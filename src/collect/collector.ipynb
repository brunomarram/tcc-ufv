# %%
import os
import sys
# !{sys.executable} -m pip install requests
import requests
import time
import pandas as pd
import numpy as np
from datetime import datetime
# Out:
# Requirement already satisfied: requests in /usr/lib/python3/dist-packages (2.23.0)

# %%
fileToRead = 'amenity_hospital'
folderToSave = 'hospitals'

bruteData = pd.read_csv('data/'+fileToRead+'.csv')

# %%
def normalizePoints(coordinate):
    coordinate = coordinate.replace("POINT (", "")
    coordinate = coordinate.replace(")", "")
    return [coordinate]

# %%
def normalizeCoordinate(coordinate):
    coordinate = coordinate.replace("POLYGON ((", "")
    coordinate = coordinate.replace("))", "")
    coordinate = coordinate.split(", ")
    return coordinate

# %%
def processCoordinates(coordinates):
    latitude = []
    longitude = []
    
    for coordinate in coordinates:
        coordinate = coordinate.split(' ')
        latitude.append(float(coordinate[0]))
        longitude.append(float(coordinate[1]))
        
    latitude = pd.Series(latitude)
    longitude = pd.Series(longitude)
    
    return latitude.mean(), longitude.mean()

# %%
def formatTweets(tweets):
    rawTweets = []
    if 'statuses' in tweets:
        for tweet in tweets['statuses']:
            rawTweets.append(tweet)
    return rawTweets

# %%
def getTweets(latitude, longitude):
    radius = '1km' # raio padrão de busca 500m
    params = { 'q': '', 'geocode': str(latitude)+','+str(longitude)+','+str(radius), count: 100 }
    headers = { 'Authorization': 'Bearer AAAAAAAAAAAAAAAAAAAAAG%2BMEQEAAAAAtfi7dEtE1aW%2Bk9bPNb6xANHHUGw%3DCf78ZkZ5goLyHZYNYBz22SoGAlWnknA0KYaGLSsJILR1bwr7kG' }
    try:
        tweets = requests.get('https://api.twitter.com/1.1/search/tweets.json', params=params, headers=headers)
        tweets = tweets.json()
    except:
        tweets = {}
    return formatTweets(tweets)

# %%
def writeTweets(place, latitude, longitude, tweets):
    filename = datetime.now().strftime("%d-%m")
    try:
        f = open("../data-manipulation/tweets/v3/"+folderToSave+"/"+filename+".csv", "a")
    except:
        f = open("../data-manipulation/tweets/v3/"+folderToSave+"/"+filename+".csv", "w+")
    f.write(str(place) + ',' + str(latitude) + "," + str(longitude) +","+ str(tweets) + '\n')
    f.close()

# %%
def collect(start, to, count, timeout):
    for place in bruteData['geom'][start:to]:
        normalized = normalizeCoordinate(place)
        if len(normalized) < 2:
            normalized = normalizePoints(place)

        longitude, latitude = processCoordinates(normalized)
        tweets = getTweets(latitude, longitude)
        writeTweets(bruteData['name'][count], latitude, longitude, tweets)
        print(count, latitude, longitude, "done!")
        count += 1

    print("                 ")
    print("-----------------")
    print("done! and wait...")
    print("-----------------")
    print("                 ")
    time.sleep(timeout)
    return count

# %%
indexControl = 0
stop = False
count = 0

while(stop != True):
    start = indexControl
    end = indexControl + 450
    if indexControl + 450 > len(bruteData['geom']):
        end = len(bruteData['geom'])
        stop = True
        
    count = collect(start, end, count, 60 * 15)

    indexControl = indexControl + 450

print("Done!! :)")
# Out:
# .60965837142857 -43.70751295714285 done!
# 2757 -18.82141137272727 -41.9839272 done!
# 2758 -15.67226598 -48.2004515 done!
# 2759 -23.495919227272726 -46.81204653636364 done!
# 3009 -23.51004644 -46.44671580000001 done!
# 3010 -25.531227440000002 -48.54484352 done!
# 3011 -21.3648502 -48.225306780000004 done!
# 3012 -23.662456016666667 -46.459785016666665 done!
# 3013 -23.686829491666668 -46.4600456625 done!
# 3014 -5.7901994375 -35.20125315 done!
# 3015 -5.34491487 -49.111330455 done!
# 3016 -23.458989041666666 -46.58199464583333 done!
# 3017 -3.1301926 -60.02503420000001 done!
# 3018 -23.08913515714286 -46.97781867142857 done!
# 3019 -23.08942672 -46.977756740000004 done!
# 3020 -23.09212984 -46.952428399999995 done!
# 3021 -23.09285836 -46.952156 done!
# 3022 -23.552089084615382 -46.67699974615385 done!
# 3023 -27.204376138461537 -49.64979401538461 done!
# 3024 -22.314761859999997 -49.11658708 done!
# 3025 -23.596264740000002 -46.60873138000001 done!
# 3026 -17.55944384 -52.54572717999999 done!
# 3027 -5.860646180000001 -35.204139500000004 done!
# 3028 -5.8282304599999994 -35.2350854 done!
# 3029 -17.5650844125 -52.556025553125004 done!
# 3030 -5.996162319999999 -42.70380709999999 done!
# 3031 -3.755909533333334 -38.51758353333333 done!
# 3032 -6.00126266 -42.70203394 done!
# 3033 -21.461247647826088 -47.580304339130436 done!
# 3034 -23.5337648 -46.68844805555555 done!
# 3035 -23.530567342857143 -46.69713698571429 done!
# 3036 -23.5333476 -46.67542743333333 done!
# 3037 -23.54143636 -46.64927094 done!
# 3038 -15.553202500000003 -56.05908206666666 done!
# 3039 -23.495635871428572 -46.625285514285714 done!
# 3040 -23.511744583333336 -46.58391776666667 done!
# 3041 -23.544904033333335 -46.59066467777777 done!
# 3042 -23.563239959999997 -46.5899977 done!
# 3043 -7.031734666666667 -37.29409891666666 done!
# 3044 -23.54034908 -46.880969519999994 done!
# 3045 -14.670375750000003 -40.4731425 done!
# 3046 -5.1418382833333345 -42.79115195 done!
# 3047 -12.770791 -39.526806900000004 done!
# 3048 -13.25810549090909 -43.41611652727273 done!
# 3049 -21.680125258333334 -45.919785225 done!
# 3050 -12.547189419999999 -38.71093282 done!
# 3051 -12.547068307142855 -38.71117888571428 done!
# 3052 -25.935594860000002 -52.1744013 done!
# 3053 -22.047462880000005 -42.6748472 done!
# 3054 -23.421163760000002 -46.556190480000005 done!
# 3055 -3.73669754 -38.646737810000005 done!
# 3056 -3.5272228599999997 -39.1722062 done!
# 3057 -23.502914459999996 -46.878135639999996 done!
# 3058 -3.7330953399999998 -38.52629126000001 done!
# 3059 -3.7314514 -38.54772218 done!
# 3060 -3.76097416 -38.53066018 done!
# 3061 -25.40110506 -52.41010222 done!
# 3062 -16.442168842857146 -39.06491585714286 done!
# 3063 -2.5428143999999997 -44.28032538333333 done!
# 3064 -17.79632524 -41.78183032 done!
# 3065 -6.4158035 -38.0128765 done!
# 3066 -6.41357332 -38.01768388000001 done!
# 3067 -20.082278922222223 -51.09685944444445 done!
# 3068 -6.7907383 -39.29418985 done!
# 3069 -23.40619284 -46.04300240444445 done!
# 3070 -3.820835445 -38.48353891000001 done!
# 3071 -3.8706643499999998 -38.4699866875 done!
# 3072 -6.211436313636364 -38.502089409090914 done!
# 3073 -23.668018816666663 -46.531696100000005 done!
# 3074 -3.6070025300000004 -38.962470530000004 done!
# 3075 -21.314117983333336 -51.83318071666667 done!
# 3076 -3.7674153499999994 -38.56081918 done!
# 3077 -22.055141250000002 -47.913447229999996 done!
# 3078 -8.358507637499999 -36.563975 done!
# 3079 -5.813299300000001 -35.20183424 done!
# 3080 -12.414732175000001 -41.76962491249999 done!
# 3081 -22.840732433333333 -45.22731688333332 done!
# 3082 -22.840523820000005 -45.22673054000001 done!
# 3083 -29.04384622 -52.29625556 done!
# 3084 -15.672541014285713 -38.946725942857135 done!
# 3085 -23.14690816 -51.772096940000004 done!
# 3086 -26.96495028571428 -52.532045814285716 done!
# 3087 -32.180083044444444 -52.156692666666665 done!
# 3088 -13.611862680000002 -42.93760486 done!
# 3089 -3.70884072 -40.333086859999995 done!
# 3090 -15.32190104 -49.1357487 done!
# 3091 -23.590900499999996 -46.62101002 done!
# 3092 -23.595205171428574 -46.62763302857143 done!
# 3093 -23.6928521 -46.55391363333334 done!
# 3094 -10.808151166666667 -55.45881075 done!
# 3095 -27.588360689999995 -48.594681035 done!
# 3096 -27.250457100000002 -49.68939174545455 done!
# 3097 -20.316984419354842 -40.34013612903227 done!
# 3098 -20.313582381196582 -40.31077152820512 done!
# 3099 -20.313457942105263 -40.30115944736842 done!
# 3100 -20.297976538759695 -40.31819775503876 done!
# 3101 -29.687023275 -51.464111421428576 done!
# 3102 -29.693867031914895 -51.48007788510638 done!
# 3103 -22.8959432125 -43.11800194999999 done!
# 3104 -22.905329422222223 -43.09742283333333 done!
# 3105 -20.499063052173913 -54.61621673478261 done!
# 3106 -22.1328058375 -51.40751950000001 done!
# 3107 -22.10679578181818 -51.389336500000006 done!
# 3108 -23.48495674772727 -46.6318251340909 done!
# 3109 -23.193673814285717 -49.762654128571434 done!
# 3110 -10.196198685365854 -48.33578951463415 done!
# 3111 -10.180926490322578 -48.90395151935485 done!
# 3112 -26.48888100232558 -49.08444902558139 done!
# 3113 -25.44658095 -49.27995061666667 done!
# 3114 -21.992067780952382 -47.8880524 done!
# 3115 -22.124731914705883 -51.41473398529411 done!
# 3116 -5.059884488888889 -42.79416544000001 done!
# 3117 2.0383850624999997 -50.791984424999995 done!
# 3118 -10.922994053846152 -37.66011083076923 done!
# 3119 -10.694469881818184 -37.42830134545455 done!
# 3120 -10.9022134875 -37.054759625 done!
# 3121 -5.070341642 -42.810785605999996 done!
# 3122 -15.547563210714287 -47.32013025357144 done!
# 3123 -20.318310169999997 -40.32300668 done!
# 3124 -20.320161899999995 -40.33814006721312 done!
# 3125 -31.39139768947368 -52.6785258631579 done!
# 3126 -29.695588345454542 -53.82753338181817 done!
# 3127 -29.67160338333333 -53.80673856666666 done!
# 3128 -29.90676782 -51.19837158 done!
# 3129 -22.107934164285716 -51.96682290714288 done!
# 3130 -22.12711668888889 -51.41366771111111 done!
# 3131 -22.840774223076927 -43.23873845384615 done!
# 3132 -19.896503680000002 -43.947420879999996 done!
# 3133 -8.0565384 -34.88516078333333 done!
# 3134 -3.7703532611111106 -38.616193816666666 done!
# 3135 -19.987098675757576 -43.986912436363646 done!
# 3136 -19.990647743750003 -43.9967972375 done!
# 3137 -22.209322099999998 -49.95786892727272 done!
# 3138 -21.192696118518516 -50.430652611111114 done!
# 3139 -28.52687121764706 -49.321862988235296 done!
# 3140 -30.029543143749997 -51.214705031250006 done!
# 3141 -22.983213141176467 -43.40391120882352 done!
# 3142 -22.894824707692308 -43.19100110769231 done!
# 3143 -5.8824133875 -38.6176916375 done!
# 3144 -21.68870558888889 -45.26558362222223 done!
# 3145 -15.801799338461539 -47.935730500000005 done!
# 3146 -15.802037352 -47.935182132 done!
# 3147 -20.66362454 -40.50006964999999 done!
# 3148 -29.901921879999996 -51.140167860000005 done!
# 3149 -28.54315872222222 -51.68927345555556 done!
#
# -----------------
# done! and wait...
# -----------------
#
# 3150 -7.226446373333332 -39.32561491333333 done!
# 3151 -7.221868863999999 -39.319792676 done!
# 3152 -21.773357119999996 -48.16695789333333 done!
# 3153 -19.92199792 -43.91985976 done!
# 3154 -10.850887752631579 -37.06952231578947 done!
# 3155 -16.08199172857143 -57.677926264285716 done!
# 3156 -3.7620596764705887 -38.57358238235294 done!
# 3157 -20.904526124999997 -47.5880845125 done!
# 3158 -19.784953880000003 -42.14273581333334 done!
# 3159 -26.972272513333333 -53.63378376000001 done!
# 3160 -19.782803884615383 -42.13719469230769 done!
# 3161 -8.047508639393941 -34.946085878787876 done!
# 3162 -23.522392672727275 -46.5627456181818 done!
# 3163 -4.362143415384615 -39.31365314615384 done!
# 3164 -29.197298250000003 -54.869582400000006 done!
# 3165 -29.693119953846157 -53.805810561538465 done!
# 3166 -21.4416833 -45.9465429 done!
# 3167 -21.431749912500003 -45.9623306375 done!
# 3168 -3.094217253333333 -60.05733746222222 done!
# 3169 -15.79816646 -48.133362919999996 done!
# 3170 -27.69778108 -52.04737268 done!
# 3171 -26.903470475 -49.08975975 done!
# 3172 -3.7424875322580644 -38.494273122580644 done!
# 3173 -3.8507070285714287 -38.59656348571429 done!
# 3174 -3.8307384631578953 -38.556885647368425 done!
# 3175 -3.8177202142857145 -38.53342488571428 done!
# 3176 -3.8159630583333333 -38.499477291666665 done!
# 3177 -3.8222055166666666 -38.4819364 done!
# 3178 -23.500502866666668 -46.85798836666666 done!
# 3179 -29.72125747272727 -52.42685470909092 done!
# 3180 -25.543320164285717 -49.19679641428571 done!
# 3181 -4.419217785 -39.04433698500001 done!
# 3182 -21.741220148571433 -48.121654285714285 done!
# 3183 -25.29650276 -48.32005644 done!
# 3184 -14.782556779999998 -57.291048919999994 done!
# 3185 -2.9981194 -60.03005091666667 done!
# 3186 -3.722134884615385 -38.52763596153846 done!
# 3187 -25.469296984210523 -49.20647436842105 done!
# 3188 -22.4734883 -46.63428682 done!
# 3189 3.8433046400000004 -51.83776974 done!
# 3190 -15.923738700000001 -48.806601214285706 done!
#
# -----------------
# done! and wait...
# -----------------
#
# Done!! :)
